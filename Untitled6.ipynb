# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("World Economic Classifications v2.csv")
df
# Out:
#                            country_name un_class_2014 imf_class_2023  g7  \
# 0                            Luxembourg     Developed       Advanced  No
# 1                             Singapore    Developing       Advanced  No
# 2                               Ireland     Developed       Advanced  No
# 3                                Norway     Developed       Advanced  No
# 4                                 Qatar    Developing       Emerging  No
# ..                                  ...           ...            ...  ..
# 200        Syrian Arab Republic (Syria)    Developing       Emerging  No
# 201                              Taiwan    Developing       Advanced  No
# 202  Venezuela (Bolivarian Republic of)    Developing       Emerging  No
# 203                               Yemen    Developing       Emerging  No
# 204                             Andorra           NaN       Advanced  No
#
#     eu_member fuel_exp_country  wealth_rank gdp_ppp_2022  gdp_pc_2022
# 0         Yes               No          1.0  $142,214.00  $127,046.00
# 1          No               No          2.0  $127,565.00   $78,115.00
# 2         Yes               No          3.0  $126,905.00  $105,362.00
# 3          No               No          4.0  $114,899.00  $106,594.00
# 4          No              Yes          5.0  $114,648.00   $88,046.00
# ..        ...              ...          ...          ...          ...
# 200        No               No          NaN          NaN          NaN
# 201        No               No          NaN          NaN          NaN
# 202        No              Yes          NaN          NaN          NaN
# 203        No              Yes          NaN          NaN          NaN
# 204        No              Yes          NaN          NaN   $41,993.00
#
# [205 rows x 9 columns]

# %%
df.isnull()
# Out:
#      country_name  un_class_2014  imf_class_2023     g7  eu_member  \
# 0           False          False           False  False      False
# 1           False          False           False  False      False
# 2           False          False           False  False      False
# 3           False          False           False  False      False
# 4           False          False           False  False      False
# ..            ...            ...             ...    ...        ...
# 170         False          False           False  False      False
# 171         False          False           False  False      False
# 172         False          False           False  False      False
# 173         False          False           False  False      False
# 174         False          False           False  False      False
#
#      fuel_exp_country  wealth_rank  gdp_ppp_2022  gdp_pc_2022
# 0               False        False         False        False
# 1               False        False         False        False
# 2               False        False         False        False
# 3               False        False         False        False
# 4               False        False         False        False
# ..                ...          ...           ...          ...
# 170             False        False         False        False
# 171             False        False         False        False
# 172             False        False         False        False
# 173             False        False         False        False
# 174             False        False         False        False
#
# [153 rows x 9 columns]

# %%
df.notnull()
# Out:
#      country_name  un_class_2014  imf_class_2023    g7  eu_member  \
# 0            True           True            True  True       True
# 1            True           True            True  True       True
# 2            True           True            True  True       True
# 3            True           True            True  True       True
# 4            True           True            True  True       True
# ..            ...            ...             ...   ...        ...
# 170          True           True            True  True       True
# 171          True           True            True  True       True
# 172          True           True            True  True       True
# 173          True           True            True  True       True
# 174          True           True            True  True       True
#
#      fuel_exp_country  wealth_rank  gdp_ppp_2022  gdp_pc_2022
# 0                True         True          True         True
# 1                True         True          True         True
# 2                True         True          True         True
# 3                True         True          True         True
# 4                True         True          True         True
# ..                ...          ...           ...          ...
# 170              True         True          True         True
# 171              True         True          True         True
# 172              True         True          True         True
# 173              True         True          True         True
# 174              True         True          True         True
#
# [153 rows x 9 columns]

# %%
df.fillna(0)
# Out:
#                            country_name un_class_2014 imf_class_2023  g7  \
# 0                            Luxembourg     Developed       Advanced  No
# 1                             Singapore    Developing       Advanced  No
# 2                               Ireland     Developed       Advanced  No
# 3                                Norway     Developed       Advanced  No
# 4                                 Qatar    Developing       Emerging  No
# ..                                  ...           ...            ...  ..
# 200        Syrian Arab Republic (Syria)    Developing       Emerging  No
# 201                              Taiwan    Developing       Advanced  No
# 202  Venezuela (Bolivarian Republic of)    Developing       Emerging  No
# 203                               Yemen    Developing       Emerging  No
# 204                             Andorra             0       Advanced  No
#
#     eu_member fuel_exp_country  wealth_rank gdp_ppp_2022  gdp_pc_2022
# 0         Yes               No          1.0  $142,214.00  $127,046.00
# 1          No               No          2.0  $127,565.00   $78,115.00
# 2         Yes               No          3.0  $126,905.00  $105,362.00
# 3          No               No          4.0  $114,899.00  $106,594.00
# 4          No              Yes          5.0  $114,648.00   $88,046.00
# ..        ...              ...          ...          ...          ...
# 200        No               No          0.0            0            0
# 201        No               No          0.0            0            0
# 202        No              Yes          0.0            0            0
# 203        No              Yes          0.0            0            0
# 204        No              Yes          0.0            0   $41,993.00
#
# [205 rows x 9 columns]

# %%
print(df['wealth_rank'].fillna(method='pad',inplace=True))
# Out:
#                      country_name un_class_2014 imf_class_2023  g7 eu_member  \
# 0                      Luxembourg     Developed       Advanced  No       Yes
# 1                       Singapore    Developing       Advanced  No        No
# 2                         Ireland     Developed       Advanced  No       Yes
# 3                          Norway     Developed       Advanced  No        No
# 4                           Qatar    Developing       Emerging  No        No
# ..                            ...           ...            ...  ..       ...
# 170                         Niger    Developing       Emerging  No        No
# 171                    Mozambique    Developing       Emerging  No        No
# 172  Democratic Republic of Congo    Developing       Emerging  No        No
# 173      Central African Republic    Developing       Emerging  No        No
# 174                       Burundi    Developing       Emerging  No        No
#
#     fuel_exp_country  wealth_rank gdp_ppp_2022  gdp_pc_2022
# 0                 No          1.0  $142,214.00  $127,046.00
# 1                 No          2.0  $127,565.00   $78,115.00
# 2                 No          3.0  $126,905.00  $105,362.00
# 3                 No          4.0  $114,899.00  $106,594.00
# 4                Yes          5.0  $114,648.00   $88,046.00
# ..               ...          ...          ...          ...
# 170               No        172.0    $1,505.00      $533.00
# 171               No        173.0    $1,468.00      $541.00
# 172               No        174.0    $1,337.00      $586.00
# 173               No        175.0      $967.00      $427.00
# 174               No        176.0      $836.00      $238.00
#
# [153 rows x 9 columns]

# %%
df.interpolate(method='linear')
# Out:
#                      country_name un_class_2014 imf_class_2023  g7 eu_member  \
# 0                      Luxembourg     Developed       Advanced  No       Yes
# 1                       Singapore    Developing       Advanced  No        No
# 2                         Ireland     Developed       Advanced  No       Yes
# 3                          Norway     Developed       Advanced  No        No
# 4                           Qatar    Developing       Emerging  No        No
# ..                            ...           ...            ...  ..       ...
# 170                         Niger    Developing       Emerging  No        No
# 171                    Mozambique    Developing       Emerging  No        No
# 172  Democratic Republic of Congo    Developing       Emerging  No        No
# 173      Central African Republic    Developing       Emerging  No        No
# 174                       Burundi    Developing       Emerging  No        No
#
#     fuel_exp_country  wealth_rank gdp_ppp_2022  gdp_pc_2022
# 0                 No          1.0  $142,214.00  $127,046.00
# 1                 No          2.0  $127,565.00   $78,115.00
# 2                 No          3.0  $126,905.00  $105,362.00
# 3                 No          4.0  $114,899.00  $106,594.00
# 4                Yes          5.0  $114,648.00   $88,046.00
# ..               ...          ...          ...          ...
# 170               No        172.0    $1,505.00      $533.00
# 171               No        173.0    $1,468.00      $541.00
# 172               No        174.0    $1,337.00      $586.00
# 173               No        175.0      $967.00      $427.00
# 174               No        176.0      $836.00      $238.00
#
# [153 rows x 9 columns]

# %%
df.dropna(axis=0,inplace=True)

# %%
df.describe()
# Out:
#        wealth_rank
# count   153.000000
# mean     85.843137
# std      52.479459
# min       1.000000
# 25%      39.000000
# 50%      82.000000
# 75%     131.000000
# max     176.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153 entries, 0 to 174
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country_name      153 non-null    object
#  1   un_class_2014     153 non-null    object
#  2   imf_class_2023    153 non-null    object
#  3   g7                153 non-null    object
#  4   eu_member         153 non-null    object
#  5   fuel_exp_country  153 non-null    object
#  6   wealth_rank       153 non-null    float64
#  7   gdp_ppp_2022      153 non-null    object
#  8   gdp_pc_2022       153 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 12.0+ KB

# %%
df.head()
# Out:
#   country_name un_class_2014 imf_class_2023  g7 eu_member fuel_exp_country  \
# 0   Luxembourg     Developed       Advanced  No       Yes               No
# 1    Singapore    Developing       Advanced  No        No               No
# 2      Ireland     Developed       Advanced  No       Yes               No
# 3       Norway     Developed       Advanced  No        No               No
# 4        Qatar    Developing       Emerging  No        No              Yes
#
#    wealth_rank gdp_ppp_2022  gdp_pc_2022
# 0          1.0  $142,214.00  $127,046.00
# 1          2.0  $127,565.00   $78,115.00
# 2          3.0  $126,905.00  $105,362.00
# 3          4.0  $114,899.00  $106,594.00
# 4          5.0  $114,648.00   $88,046.00

# %%
df.tail()
# Out:
#                      country_name un_class_2014 imf_class_2023  g7 eu_member  \
# 170                         Niger    Developing       Emerging  No        No
# 171                    Mozambique    Developing       Emerging  No        No
# 172  Democratic Republic of Congo    Developing       Emerging  No        No
# 173      Central African Republic    Developing       Emerging  No        No
# 174                       Burundi    Developing       Emerging  No        No
#
#     fuel_exp_country  wealth_rank gdp_ppp_2022 gdp_pc_2022
# 170               No        172.0    $1,505.00     $533.00
# 171               No        173.0    $1,468.00     $541.00
# 172               No        174.0    $1,337.00     $586.00
# 173               No        175.0      $967.00     $427.00
# 174               No        176.0      $836.00     $238.00

# %%
plt.plot( df.gdp_ppp_2022,df.wealth_rank)
plt.show()

# %%
plt.bar(df.country_name,df.wealth_rank)
plt.show()
